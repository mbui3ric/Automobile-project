# %% [markdown]
# #PROJECT ON AUTOMOBILE DATA SET.
# #Q - RETRIEVE ALL THE INFORMATION ABOUT ALL THE CARS IN THE DATASET.

# %%
import pandas as pd 
Automobile_df = pd.read_csv("Automobile data.csv")
Automobile_df
# Out:
#       Brand Name Fuel type Aspiration Door Panel       Design Wheel Drive  \
# 0    alfa-romero       gas        std        two  convertible         rwd
# 1    alfa-romero       gas        std        two  convertible         rwd
# 2    alfa-romero       gas        std        two    hatchback         rwd
# 3           audi       gas        std       four        sedan         fwd
# 4           audi       gas        std       four        sedan         4wd
# ..           ...       ...        ...        ...          ...         ...
# 200        volvo       gas        std       four        sedan         rwd
# 201        volvo       gas      turbo       four        sedan         rwd
# 202        volvo       gas        std       four        sedan         rwd
# 203        volvo    diesel      turbo       four        sedan         rwd
# 204        volvo       gas      turbo       four        sedan         rwd
#
#     Engine Location Engine Type Cylinder Count  Engine Size Fuel System  Bore  \
# ...

# %% [markdown]
# # Q  HOW MANY CARS ARE THER IN THE DATA SET IN TOTAL

# %%
Automobile_df.shape
# Out:
# (205, 19)

# %%
#With the above results of 205 and 19,means that there are 205 rows and 19 columns hence the number of cars being 205.

# %% [markdown]
# # Q LIST ALL THE DIFFERENT BRANDS OF CARS IN THE DATA SET

# %%
Automobile_brand_df = Automobile_df["Brand Name"].unique()
Automobile_brand_df
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %% [markdown]
# # Q SHOW THE CARS THAT USE GASOLINE AS FUEL

# %%
Automobile_gas_df = Automobile_df["Fuel type"] =="gas"
Automobile_gas_df
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 200     True
# 201     True
# 202     True
# 203    False
# 204     True
# Name: Fuel type, Length: 205, dtype: bool

# %%
#Below is the dataset of cars that use gasoline only.

# %%
Automobile_df[Automobile_gas_df]
# Out:
#       Brand Name Fuel type Aspiration Door Panel       Design Wheel Drive  \
# 0    alfa-romero       gas        std        two  convertible         rwd
# 1    alfa-romero       gas        std        two  convertible         rwd
# 2    alfa-romero       gas        std        two    hatchback         rwd
# 3           audi       gas        std       four        sedan         fwd
# 4           audi       gas        std       four        sedan         4wd
# ..           ...       ...        ...        ...          ...         ...
# 199        volvo       gas      turbo       four        wagon         rwd
# 200        volvo       gas        std       four        sedan         rwd
# 201        volvo       gas      turbo       four        sedan         rwd
# 202        volvo       gas        std       four        sedan         rwd
# 204        volvo       gas      turbo       four        sedan         rwd
#
#     Engine Location Engine Type Cylinder Count  Engine Size Fuel System  Bore  \
# ...

# %% [markdown]
# #  Q WHAT IS THE AVERAGE SIZE OF ENGINES IN ALL CARS?

# %%
Automobile_average_engine_df = Automobile_df["Engine Size"].mean()
Automobile_average_engine_df
# Out:
# 126.90731707317073

# %% [markdown]
# # Q DISPLAY CARS WITH PRICES HIGHER THAN $30000.

# %%
Automobile_more_price_df = Automobile_df[["Brand Name","Price in Dollars"]]["Price in Dollars"] > 30000
Automobile_more_price_df
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Name: Price in Dollars, Length: 205, dtype: bool

# %%
Automobile_df[Automobile_more_price_df]
# Out:
#         Brand Name Fuel type Aspiration Door Panel       Design Wheel Drive  \
# 15             bmw       gas        std       four        sedan         rwd
# 16             bmw       gas        std        two        sedan         rwd
# 17             bmw       gas        std       four        sedan         rwd
# 44           isuzu       gas        std        two        sedan         fwd
# 47          jaguar       gas        std       four        sedan         rwd
# 48          jaguar       gas        std       four        sedan         rwd
# 49          jaguar       gas        std        two        sedan         rwd
# 70   mercedes-benz    diesel      turbo       four        sedan         rwd
# 71   mercedes-benz       gas        std       four        sedan         rwd
# 72   mercedes-benz       gas        std        two  convertible         rwd
# 73   mercedes-benz       gas        std       four        sedan         rwd
# ...

# %% [markdown]
# # Q WHICH BRAND HAS THE CAR WITH HIGHEST HORSEPOWER AND HOW MUCH IS IT?

# %%
Automobile_high_horse_df =Automobile_df.sort_values(["Horse Power"], ascending =False)
Automobile_high_horse_df
# Out:
#      Brand Name Fuel type Aspiration Door Panel       Design Wheel Drive  \
# 129     porsche       gas        std        two    hatchback         rwd
# 49       jaguar       gas        std        two        sedan         rwd
# 128     porsche       gas        std        two  convertible         rwd
# 127     porsche       gas        std        two      hardtop         rwd
# 126     porsche       gas        std        two      hardtop         rwd
# ..          ...       ...        ...        ...          ...         ...
# 159      toyota    diesel        std       four    hatchback         fwd
# 90       nissan    diesel        std        two        sedan         fwd
# 184  volkswagen    diesel        std       four        sedan         fwd
# 182  volkswagen    diesel        std        two        sedan         fwd
# 18    chevrolet       gas        std        two    hatchback         fwd
#
#     Engine Location Engine Type Cylinder Count  Engine Size Fuel System  Bore  \
# ...

# %%
# A -porsche has the highest horse Power which is 288

# %% [markdown]
# #  Q  - LIST THE CARS WITH THE ENGINES LOCATED  AT THE FRONT

# %%
Automobile_df
# Out:
#       Brand Name Fuel type Aspiration Door Panel       Design Wheel Drive  \
# 0    alfa-romero       gas        std        two  convertible         rwd
# 1    alfa-romero       gas        std        two  convertible         rwd
# 2    alfa-romero       gas        std        two    hatchback         rwd
# 3           audi       gas        std       four        sedan         fwd
# 4           audi       gas        std       four        sedan         4wd
# ..           ...       ...        ...        ...          ...         ...
# 200        volvo       gas        std       four        sedan         rwd
# 201        volvo       gas      turbo       four        sedan         rwd
# 202        volvo       gas        std       four        sedan         rwd
# 203        volvo    diesel      turbo       four        sedan         rwd
# 204        volvo       gas      turbo       four        sedan         rwd
#
#     Engine Location Engine Type Cylinder Count  Engine Size Fuel System  Bore  \
# ...

# %%
Automobile_infront_df = Automobile_df[["Brand Name","Engine Location"]]["Engine Location"] == "front"
Automobile_infront_df
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 200    True
# 201    True
# 202    True
# 203    True
# 204    True
# Name: Engine Location, Length: 205, dtype: bool

# %%
Automobile_df[Automobile_infront_df]
# Out:
#       Brand Name Fuel type Aspiration Door Panel       Design Wheel Drive  \
# 0    alfa-romero       gas        std        two  convertible         rwd
# 1    alfa-romero       gas        std        two  convertible         rwd
# 2    alfa-romero       gas        std        two    hatchback         rwd
# 3           audi       gas        std       four        sedan         fwd
# 4           audi       gas        std       four        sedan         4wd
# ..           ...       ...        ...        ...          ...         ...
# 200        volvo       gas        std       four        sedan         rwd
# 201        volvo       gas      turbo       four        sedan         rwd
# 202        volvo       gas        std       four        sedan         rwd
# 203        volvo    diesel      turbo       four        sedan         rwd
# 204        volvo       gas      turbo       four        sedan         rwd
#
#     Engine Location Engine Type Cylinder Count  Engine Size Fuel System  Bore  \
# ...

# %% [markdown]
# # Q - HOW MANY CARS ARE THERE FOR EACH TYPE OF FUEL

# %%
Automobile_fuel_group_df = Automobile_df.groupby("Fuel type")
Automobile_fuel_group_df

# %%
Automobile_total_fuel_df = Automobile_fuel_group_df["Brand Name"].count()
Automobile_total_fuel_df
# Out:
# Fuel type
# diesel     20
# gas       185
# Name: Brand Name, dtype: int64

# %% [markdown]
# # Q - WHAT IS THE AVERAGE CITY MILEAGE FOR CARS WITH MORE THAN 4 CYLINDERS

# %%
Automobile_df
# Out:
#       Brand Name Fuel type Aspiration Door Panel       Design Wheel Drive  \
# 0    alfa-romero       gas        std        two  convertible         rwd
# 1    alfa-romero       gas        std        two  convertible         rwd
# 2    alfa-romero       gas        std        two    hatchback         rwd
# 3           audi       gas        std       four        sedan         fwd
# 4           audi       gas        std       four        sedan         4wd
# ..           ...       ...        ...        ...          ...         ...
# 200        volvo       gas        std       four        sedan         rwd
# 201        volvo       gas      turbo       four        sedan         rwd
# 202        volvo       gas        std       four        sedan         rwd
# 203        volvo    diesel      turbo       four        sedan         rwd
# 204        volvo       gas      turbo       four        sedan         rwd
#
#     Engine Location Engine Type Cylinder Count  Engine Size Fuel System  Bore  \
# ...

# %%
Automobile_cylinder_df = Automobile_df["Cylinder Count"] == "four"
Automobile_cylinder_df
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 200     True
# 201     True
# 202    False
# 203    False
# 204     True
# Name: Cylinder Count, Length: 205, dtype: bool

# %%
Automobile_df[Automobile_cylinder_df]["City Mileage"].mean()
# Out:
# 27.11949685534591

# %% [markdown]
# # Q --FOR EACH BRAND ,WHAT IS THE AVERAGE PRICE OF CARS WITH REAR_WHEEL DRIVE?

# %%
Automobile_df
# Out:
#       Brand Name Fuel type Aspiration Door Panel       Design Wheel Drive  \
# 0    alfa-romero       gas        std        two  convertible         rwd
# 1    alfa-romero       gas        std        two  convertible         rwd
# 2    alfa-romero       gas        std        two    hatchback         rwd
# 3           audi       gas        std       four        sedan         fwd
# 4           audi       gas        std       four        sedan         4wd
# ..           ...       ...        ...        ...          ...         ...
# 200        volvo       gas        std       four        sedan         rwd
# 201        volvo       gas      turbo       four        sedan         rwd
# 202        volvo       gas        std       four        sedan         rwd
# 203        volvo    diesel      turbo       four        sedan         rwd
# 204        volvo       gas      turbo       four        sedan         rwd
#
#     Engine Location Engine Type Cylinder Count  Engine Size Fuel System  Bore  \
# ...

# %%
#TOTAL ROWS DISPLAY
from  IPython.display import display
with pd.option_context("display.max_row",205):
    display(Automobile_df)
# Out:
#         Brand Name Fuel type Aspiration Door Panel       Design Wheel Drive  \
# 0      alfa-romero       gas        std        two  convertible         rwd
# 1      alfa-romero       gas        std        two  convertible         rwd
# 2      alfa-romero       gas        std        two    hatchback         rwd
# 3             audi       gas        std       four        sedan         fwd
# 4             audi       gas        std       four        sedan         4wd
# 5             audi       gas        std        two        sedan         fwd
# 6             audi       gas        std       four        sedan         fwd
# 7             audi       gas        std       four        wagon         fwd
# 8             audi       gas      turbo       four        sedan         fwd
# 9             audi       gas      turbo        two    hatchback         4wd
# 10             bmw       gas        std        two        sedan         rwd
# ...

# %%
 Automobile_rwd_df=Automobile_df["Wheel Drive"] == "rwd"
Automobile_rwd_df
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 200     True
# 201     True
# 202     True
# 203     True
# 204     True
# Name: Wheel Drive, Length: 205, dtype: bool

# %%
Automobile_df[Automobile_rwd_df]
# Out:
#       Brand Name Fuel type Aspiration Door Panel       Design Wheel Drive  \
# 0    alfa-romero       gas        std        two  convertible         rwd
# 1    alfa-romero       gas        std        two  convertible         rwd
# 2    alfa-romero       gas        std        two    hatchback         rwd
# 10           bmw       gas        std        two        sedan         rwd
# 11           bmw       gas        std       four        sedan         rwd
# ..           ...       ...        ...        ...          ...         ...
# 200        volvo       gas        std       four        sedan         rwd
# 201        volvo       gas      turbo       four        sedan         rwd
# 202        volvo       gas        std       four        sedan         rwd
# 203        volvo    diesel      turbo       four        sedan         rwd
# 204        volvo       gas      turbo       four        sedan         rwd
#
#     Engine Location Engine Type Cylinder Count  Engine Size Fuel System  Bore  \
# ...

# %%
from  IPython.display import display
with pd.option_context("display.max_row",205):
    display(Automobile_df[Automobile_rwd_df])
# Out:
#         Brand Name Fuel type Aspiration Door Panel       Design Wheel Drive  \
# 0      alfa-romero       gas        std        two  convertible         rwd
# 1      alfa-romero       gas        std        two  convertible         rwd
# 2      alfa-romero       gas        std        two    hatchback         rwd
# 10             bmw       gas        std        two        sedan         rwd
# 11             bmw       gas        std       four        sedan         rwd
# 12             bmw       gas        std        two        sedan         rwd
# 13             bmw       gas        std       four        sedan         rwd
# 14             bmw       gas        std       four        sedan         rwd
# 15             bmw       gas        std       four        sedan         rwd
# 16             bmw       gas        std        two        sedan         rwd
# 17             bmw       gas        std       four        sedan         rwd
# ...

# %%
Automobile_grouped_rwd_df = Automobile_df[Automobile_rwd_df].groupby("Brand Name")["Price in Dollars"].mean()
Automobile_grouped_rwd_df
# Out:
# Brand Name
# alfa-romero      15498.333333
# bmw              26118.750000
# isuzu             8916.500000
# jaguar           34600.000000
# mazda            14784.000000
# mercedes-benz    33647.000000
# mercury          16503.000000
# nissan           18432.333333
# peugot           15489.090909
# plymouth         12764.000000
# porsche          28888.400000
# toyota           11973.000000
# volvo            18063.181818
# Name: Price in Dollars, dtype: float64

# %% [markdown]
# # Q  RETRIEVE CARS WITH TOP RPM OVER 7000.

# %%
Automobile_df
# Out:
#       Brand Name Fuel type Aspiration Door Panel       Design Wheel Drive  \
# 0    alfa-romero       gas        std        two  convertible         rwd
# 1    alfa-romero       gas        std        two  convertible         rwd
# 2    alfa-romero       gas        std        two    hatchback         rwd
# 3           audi       gas        std       four        sedan         fwd
# 4           audi       gas        std       four        sedan         4wd
# ..           ...       ...        ...        ...          ...         ...
# 200        volvo       gas        std       four        sedan         rwd
# 201        volvo       gas      turbo       four        sedan         rwd
# 202        volvo       gas        std       four        sedan         rwd
# 203        volvo    diesel      turbo       four        sedan         rwd
# 204        volvo       gas      turbo       four        sedan         rwd
#
#     Engine Location Engine Type Cylinder Count  Engine Size Fuel System  Bore  \
# ...

# %%
Automobile_rpm_df = Automobile_df["Top-RPM"] >7000
Automobile_rpm_df
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Name: Top-RPM, Length: 205, dtype: bool

# %%
Automobile_df[Automobile_rpm_df].sum()
# Out:
# Brand Name             0
# Fuel type              0
# Aspiration             0
# Door Panel             0
# Design                 0
# Wheel Drive            0
# Engine Location        0
# Engine Type            0
# Cylinder Count         0
# Engine Size            0
# Fuel System            0
# Bore                 0.0
# Stroke               0.0
# Compression Ratio    0.0
# Horse Power            0
# Top-RPM                0
# City Mileage           0
# Highway Mileage        0
# Price in Dollars       0
# dtype: object

# %%
from IPython.display import display
with pd.option_context("display.max_row",205):
    display(Automobile_df)
# Out:
#         Brand Name Fuel type Aspiration Door Panel       Design Wheel Drive  \
# 0      alfa-romero       gas        std        two  convertible         rwd
# 1      alfa-romero       gas        std        two  convertible         rwd
# 2      alfa-romero       gas        std        two    hatchback         rwd
# 3             audi       gas        std       four        sedan         fwd
# 4             audi       gas        std       four        sedan         4wd
# 5             audi       gas        std        two        sedan         fwd
# 6             audi       gas        std       four        sedan         fwd
# 7             audi       gas        std       four        wagon         fwd
# 8             audi       gas      turbo       four        sedan         fwd
# 9             audi       gas      turbo        two    hatchback         4wd
# 10             bmw       gas        std        two        sedan         rwd
# ...

# %%
Automobile_more_df = Automobile_df["Top-RPM"] > 7000
Automobile_more_df
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Name: Top-RPM, Length: 205, dtype: bool

# %%
Automobile_df[Automobile_more_df]
# Out:
# Empty DataFrame
# Columns: [Brand Name, Fuel type, Aspiration, Door Panel, Design, Wheel Drive, Engine Location, Engine Type, Cylinder Count, Engine Size, Fuel System, Bore, Stroke, Compression Ratio, Horse Power, Top-RPM, City Mileage, Highway Mileage, Price in Dollars]
# Index: []

# %%
# A   NONE OF THE CARS WERE ABOVE 7000 RMP

# %% [markdown]
# # Q    DISPLAY CARS WITH 4 DOORS AND A FRONT ENGINE LOCATED

# %%
Automobile_df
# Out:
#       Brand Name Fuel type Aspiration Door Panel       Design Wheel Drive  \
# 0    alfa-romero       gas        std        two  convertible         rwd
# 1    alfa-romero       gas        std        two  convertible         rwd
# 2    alfa-romero       gas        std        two    hatchback         rwd
# 3           audi       gas        std       four        sedan         fwd
# 4           audi       gas        std       four        sedan         4wd
# ..           ...       ...        ...        ...          ...         ...
# 200        volvo       gas        std       four        sedan         rwd
# 201        volvo       gas      turbo       four        sedan         rwd
# 202        volvo       gas        std       four        sedan         rwd
# 203        volvo    diesel      turbo       four        sedan         rwd
# 204        volvo       gas      turbo       four        sedan         rwd
#
#     Engine Location Engine Type Cylinder Count  Engine Size Fuel System  Bore  \
# ...

# %%
Automobile_four_df = Automobile_df["Door Panel"] == "four"
Automobile_four_df
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 200     True
# 201     True
# 202     True
# 203     True
# 204     True
# Name: Door Panel, Length: 205, dtype: bool

# %%
Auto_four_df = Automobile_df[Automobile_four_df]
Auto_four_df
# Out:
#     Brand Name Fuel type Aspiration Door Panel Design Wheel Drive  \
# 3         audi       gas        std       four  sedan         fwd
# 4         audi       gas        std       four  sedan         4wd
# 6         audi       gas        std       four  sedan         fwd
# 7         audi       gas        std       four  wagon         fwd
# 8         audi       gas      turbo       four  sedan         fwd
# ..         ...       ...        ...        ...    ...         ...
# 200      volvo       gas        std       four  sedan         rwd
# 201      volvo       gas      turbo       four  sedan         rwd
# 202      volvo       gas        std       four  sedan         rwd
# 203      volvo    diesel      turbo       four  sedan         rwd
# 204      volvo       gas      turbo       four  sedan         rwd
#
#     Engine Location Engine Type Cylinder Count  Engine Size Fuel System  Bore  \
# 3             front         ohc           four          109        mpfi  3.19
# ...

# %%
Auto_front_df = Auto_four_df["Engine Location"] == "front"
Auto_front_df
# Out:
# 3      True
# 4      True
# 6      True
# 7      True
# 8      True
#        ...
# 200    True
# 201    True
# 202    True
# 203    True
# 204    True
# Name: Engine Location, Length: 114, dtype: bool

# %%
Auto_four_df[Auto_front_df]
# Out:
#     Brand Name Fuel type Aspiration Door Panel Design Wheel Drive  \
# 3         audi       gas        std       four  sedan         fwd
# 4         audi       gas        std       four  sedan         4wd
# 6         audi       gas        std       four  sedan         fwd
# 7         audi       gas        std       four  wagon         fwd
# 8         audi       gas      turbo       four  sedan         fwd
# ..         ...       ...        ...        ...    ...         ...
# 200      volvo       gas        std       four  sedan         rwd
# 201      volvo       gas      turbo       four  sedan         rwd
# 202      volvo       gas        std       four  sedan         rwd
# 203      volvo    diesel      turbo       four  sedan         rwd
# 204      volvo       gas      turbo       four  sedan         rwd
#
#     Engine Location Engine Type Cylinder Count  Engine Size Fuel System  Bore  \
# 3             front         ohc           four          109        mpfi  3.19
# ...

# %%
# A CARS WITH 4 DOORS AND FRONT DOORS LOCATED
# DISPLAYING MAX ROWS. 
from IPython.display import display
with pd.option_context("display.max_row",114):
    display(Auto_four_df[Auto_front_df])
# Out:
#         Brand Name Fuel type Aspiration Door Panel     Design Wheel Drive  \
# 3             audi       gas        std       four      sedan         fwd
# 4             audi       gas        std       four      sedan         4wd
# 6             audi       gas        std       four      sedan         fwd
# 7             audi       gas        std       four      wagon         fwd
# 8             audi       gas      turbo       four      sedan         fwd
# 11             bmw       gas        std       four      sedan         rwd
# 13             bmw       gas        std       four      sedan         rwd
# 14             bmw       gas        std       four      sedan         rwd
# 15             bmw       gas        std       four      sedan         rwd
# 17             bmw       gas        std       four      sedan         rwd
# 20       chevrolet       gas        std       four      sedan         fwd
# 24           dodge       gas        std       four  hatchback         fwd
# ...

# %% [markdown]
# # CALCULATE THE AVERAGE ENGINE SIZE  FOR CARS PRICED OVER $50000

# %%
Automobile_sum_df= Automobile_df["Price in Dollars"] >= 50000
Automobile_sum_df
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 200    False
# 201    False
# 202    False
# 203    False
# 204    False
# Name: Price in Dollars, Length: 205, dtype: bool

# %%
Automobile_df[Automobile_sum_df].sum()
# Out:
# Brand Name            isuzu
# Fuel type               gas
# Aspiration              std
# Door Panel              two
# Design                sedan
# Wheel Drive             fwd
# Engine Location       front
# Engine Type             ohc
# Cylinder Count         four
# Engine Size              90
# Fuel System            2bbl
# Bore                   3.03
# Stroke                 3.11
# Compression Ratio       9.6
# Horse Power              70
# Top-RPM                5400
# City Mileage             38
# Highway Mileage          43
# Price in Dollars     581758
# dtype: object

# %%
# A SINCE THERE IS ONLY ONE CAR WITH A PRICE OVER 50000,THE ENGINE SIZE REMAIN CONSTANT AT 90.

# %% [markdown]
# #  Q FIND THE BRAND WITH THE MOST CARS IN THE DATA SET

# %%
Auto_count_df = Automobile_df.groupby("Brand Name")["Brand Name"].count()
Auto_count_df
# Out:
# Brand Name
# alfa-romero       3
# audi              7
# bmw               8
# chevrolet         3
# dodge             9
# honda            13
# isuzu             4
# jaguar            3
# mazda            17
# mercedes-benz     8
# mercury           1
# mitsubishi       13
# nissan           18
# peugot           11
# plymouth          7
# porsche           5
# renault           2
# saab              6
# subaru           12
# toyota           32
# volkswagen       12
# volvo            11
# Name: Brand Name, dtype: int64

# %%
# A   TOYOTA HAS THE MOST CARS AT 32 CAR.

# %%
Automobile_ascending_df = Automobile_df.sort_values(["Brand Name"], ascending = True)
Automobile_ascending_df
# Out:
#       Brand Name Fuel type Aspiration Door Panel       Design Wheel Drive  \
# 0    alfa-romero       gas        std        two  convertible         rwd
# 1    alfa-romero       gas        std        two  convertible         rwd
# 2    alfa-romero       gas        std        two    hatchback         rwd
# 3           audi       gas        std       four        sedan         fwd
# 4           audi       gas        std       four        sedan         4wd
# ..           ...       ...        ...        ...          ...         ...
# 199        volvo       gas      turbo       four        wagon         rwd
# 200        volvo       gas        std       four        sedan         rwd
# 201        volvo       gas      turbo       four        sedan         rwd
# 202        volvo       gas        std       four        sedan         rwd
# 204        volvo       gas      turbo       four        sedan         rwd
#
#     Engine Location Engine Type Cylinder Count  Engine Size Fuel System  Bore  \
# ...

# %%
from IPython.display import display
with pd.option_context("display.max_row",205):
    display(Automobile_ascending_df )
# Out:
#         Brand Name Fuel type Aspiration Door Panel       Design Wheel Drive  \
# 0      alfa-romero       gas        std        two  convertible         rwd
# 1      alfa-romero       gas        std        two  convertible         rwd
# 2      alfa-romero       gas        std        two    hatchback         rwd
# 3             audi       gas        std       four        sedan         fwd
# 4             audi       gas        std       four        sedan         4wd
# 5             audi       gas        std        two        sedan         fwd
# 6             audi       gas        std       four        sedan         fwd
# 7             audi       gas        std       four        wagon         fwd
# 8             audi       gas      turbo       four        sedan         fwd
# 9             audi       gas      turbo        two    hatchback         4wd
# 17             bmw       gas        std       four        sedan         rwd
# ...

# %% [markdown]
# # Q SHOW CARS WITH TURBO ASPIRATION AND V6 ENGINE TYPE

# %%
Automobile_turbo_df = Automobile_df["Aspiration"] == "turbo"
Automobile_turbo_df
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 200    False
# 201     True
# 202    False
# 203     True
# 204     True
# Name: Aspiration, Length: 205, dtype: bool

# %%
Automobile_six_df = Automobile_df[Automobile_turbo_df]["Cylinder Count"] == "six"
Automobile_six_df
# Out:
# 8      False
# 9      False
# 23     False
# 27     False
# 29     False
# 67     False
# 68     False
# 69     False
# 70     False
# 75     False
# 79     False
# 80     False
# 82     False
# 83     False
# 84     False
# 87     False
# 105     True
# 108    False
# 110    False
# 112    False
# 114    False
# 116    False
# 117    False
# 119    False
# 124    False
# 136    False
# 137    False
# 145    False
# 149    False
# 174    False
# 187    False
# 192    False
# 198    False
# 199    False
# 201    False
# 203     True
# 204    False
# Name: Cylinder Count, dtype: bool

# %%
Automobile_df.at[105,"Brand Name"]
# Out:
# 'nissan'

# %%
Automobile_df.at[203,"Brand Name"]
# Out:
# 'volvo'
